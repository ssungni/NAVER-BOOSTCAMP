# %% [markdown]
# # **Data type & Basic Functions**
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/BoostcampAITech/lecture-note-python-basics-for-ai/blob/main/codes/pytorch/07_torch-study/torch_basics.ipynb)
#
# ### 1) 실습 개요
# 이번 실습에서는 Tensor의 다양한 데이터 타입과 타입 캐스팅 방법에 대해 학습합니다. 또한 Tensor를 다루는 함수와 메서드들을 사용해보며 각각의 역할을 익혀봅니다.
#
# ### 2) 실습 진행 목적 및 배경
# PyTorch에서 데이터 타입을 이해하는 것은 매우 중요합니다. AI 학습 및 활용시 알맞은 데이터 타입을 사용하지 않으면 의도와는 다른 결과물을 얻을 수 있습니다. 또한 Tensor를 다루는 여러 함수와 메서드들을 배움으로써 AI 개발에 유용하게 사용할 수 있습니다.
#
# ### 3) 실습 수행으로 얻어갈 수 있는 역량
# - 실습을 통해 다양한 데이터 타입의 코드 표현을 알맞게 사용할 수 있다.
# - 실습을 통해 Tensor의 데이터 타입을 올바르게 변환시킬 수 있다.
# - 실습을 통해 Tensor의 요소를 반환하거나 계산하는 함수를 활용할 수 있다.
# - 실습을 통해 Tensor의 특성들을 확인할 수 있다.
#
# ### 4) 실습 핵심 내용
# &nbsp;&nbsp; 1.1 PyTorch의 데이터 타입<br>
# &nbsp;&nbsp; 1.2 타입 캐스팅<br>
# &nbsp;&nbsp; 2.1 Tensor의 요소를 반환하거나 계산하는 함수<br>
# &nbsp;&nbsp; 2.2 Tensor의 특성을 확인하는 메서드<br>
#
# ### 5) Required Package
# ```
# pytorch >= 2.0.0
# matplotlib >= 3.7.1
# ```

# %% [markdown]
# # **1. PyTorch의 데이터 타입**

# %%
import torch

# %% [markdown]
# **1.1 PyTorch의 데이터 타입**

# %%
# 정수형 데이터 타입 코드 표현 실습
# 8비트 부호가 없는 정수 코드 표현 실습

a = torch.tensor(1, dtype = torch.uint8)
print('a = ', a)
print('a.dtype =', a.dtype)
# Out:
# a =  tensor(1, dtype=torch.uint8)
# a.dtype = torch.uint8

# %%
# 8비트 부호 있는 정수 코드 표현 실습

b = torch.tensor(-1, dtype = torch.int8)
print('b = ', b)
print('b.dtype =', b.dtype)
# Out:
# b =  tensor(-1, dtype=torch.int8)
# b.dtype = torch.int8

# %%
# 8비트 부호 없는 정수 코드 표현 실습

c = torch.tensor(-1, dtype = torch.uint8)
print('c = ', c)
print('c.dtype =', c.dtype)
# Out:
# c =  tensor(255, dtype=torch.uint8)
# c.dtype = torch.uint8

# %%
# 16비트 부호 있는 정수 코드 표현 실습

d = torch.tensor(1, dtype = torch.short)
print('d = ', d)
print('d.dtype =', d.dtype)
# Out:
# d =  tensor(1, dtype=torch.int16)
# d.dtype = torch.int16

# %%
# 32비트 부호 있는 정수 코드 표현 실습

e = torch.tensor(2, dtype = torch.int)
print('e = ', e)
print('e.dtype =', e.dtype)
# Out:
# e =  tensor(2, dtype=torch.int32)
# e.dtype = torch.int32

# %%
# 64비트 부호 있는 정수 코드 표현 실습

f = torch.tensor([[1, 2, 3],
                  [4, 5, 6]], dtype = torch.long)
print('f = ', f)
print('f.dtype =', f.dtype)
# Out:
# f =  tensor([[1, 2, 3],
#         [4, 5, 6]])
# f.dtype = torch.int64

# %%
# 실수형 데이터 타입 코드 표현 실습
# 32비트 부동 소수점 수의 코드 표현 실습

g = torch.tensor(1, dtype = torch.float32)
print('g = ', g)
print('g.dtype =', g.dtype)
# Out:
# g =  tensor(1.)
# g.dtype = torch.float32

# %%
# 64비트 부동 소수점 수의 코드 표현 실습

h = torch.tensor([[1, 2, 3],
                  [4, 5, 6]], dtype = torch.double)
print('h = ', h)
print('h.dtype =', h.dtype)
# Out:
# h =  tensor([[1., 2., 3.],
#         [4., 5., 6.]], dtype=torch.float64)
# h.dtype = torch.float64

# %% [markdown]
# **1.2 타입 캐스팅**

# %%
# 타입 캐스팅 코드 표현 실습
# 32비트 부동 소수점 수로 변환 코드 표현 실습

i = torch.tensor([2, 3, 4], dtype = torch.int8)
j = i.float()
print('j.dtype = ', j.dtype)
# Out:
# j.dtype =  torch.float32

# %%
# 64비트 부동 소수점 수로 변환 코드 표현

k = i.double()
print('k.dtype = ', k.dtype)
# Out:
# k.dtype =  torch.float64

# %% [markdown]
# # **2. Tensor의 기초 함수 및 메서드**

# %% [markdown]
# **2.1 Tensor의 요소를 반환하거나 계산하는 함수**

# %%
# Tensor의 요소를 반환하거나 계산하는 함수의 코드 표현 실습
# min() 함수의 코드 표현 실습

l = torch.tensor([[1, 2, 3],
                  [3, 4, 5]], dtype = torch.float)

print('torch.min(l) =', torch.min(l))
# Out:
# torch.min(l) = tensor(1.)

# %%
# max() 함수의 코드 표현 실습

print('torch.max(l) =', torch.max(l))
# Out:
# torch.max(l) = tensor(5.)

# %%
# sum() 함수의 코드 표현 실습

print('torch.sum(l) =', torch.sum(l))
# Out:
# torch.sum(l) = tensor(18.)

# %%
# prod() 함수의 코드 표현 실습

print('torch.prod(l) =', torch.prod(l))
# Out:
# torch.prod(l) = tensor(360.)

# %%
# mean() 함수의 코드 표현 실습

print('torch.mean(l) =', torch.mean(l))
# Out:
# torch.mean(l) = tensor(3.)

# %%
# var() 함수의 코드 표현 실습

print('torch.var(l) =', torch.var(l))
# Out:
# torch.var(l) = tensor(2.)

# %%
# std() 함수의 코드 표현 실습

print('torch.std(l) =', torch.std(l))
# Out:
# torch.std(l) = tensor(1.4142)

# %% [markdown]
# **2.2 Tensor의 특성을 확인하는 메서드**

# %%
# Tensor의 차원의 수를 확인하는 코드 표현 실습

print('l.dim() = ', l.dim())
# Out:
# l.dim() =  2

# %%
# Tensor의 모양(크기)를 확인하는 코드 표현 실습

l.size()
print('l.size() = ', l.size())
# Out:
# l.size() =  torch.Size([2, 3])

# %%
l.shape
print('l.shape = ', l.shape)
# Out:
# l.shape =  torch.Size([2, 3])

# %%
# Tensor의 요소의 총 개수를 확인하는 코드 표현 실습

l.numel()
print('l.numel() = ', l.numel())
# Out:
# l.numel() =  6

# %% [markdown]
# ## 콘텐츠 라이선스
#
# <hr style="height:5px;border:none;color:#5F71F7;background-color:#5F71F7">
#
# <font color='red'><b>WARNING</font> : 본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다. 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다. </b>
